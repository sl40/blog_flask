# %%
from pyecharts import Bar
from helper.date import Date
from model.third_api.dingding import RobotDing
from model.third_api.waka_time import WakaTime
# bar.use_theme('vintage')

date =Date.now().format(full=False)
data = WakaTime().get_data_by_day(date)
data['projects']
project=[]
project_time=[]
total=data['categories'][0].get('text')
for _ in data['projects']:
    project_time.append(round(_.get('total_seconds',0)/3600,2))
    project.append(_.get('name'))
bar = Bar('今日编程时间:'+total,date)
bar.add('项目', project,project_time,is_label_show=True)
bar.use_theme("vintage")

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6985f2b1aeda4a0b9a336c5e606aa710" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'vintage'], function(echarts) {
#
# var myChart_6985f2b1aeda4a0b9a336c5e606aa710 = echarts.init(document.getElementById('6985f2b1aeda4a0b9a336c5e606aa710'), 'vintage', {renderer: 'canvas'});
#
# var option_6985f2b1aeda4a0b9a336c5e606aa710 = {
#     "title": [
#         {
#             "text": "\u4eca\u65e5\u7f16\u7a0b\u65f6\u95f4:13 mins",
#             "subtext": "2019-04-01",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6430516,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9879\u76ee",
#             "data": [
#                 0.22
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6430516
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9879\u76ee"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "flask"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_6985f2b1aeda4a0b9a336c5e606aa710.setOption(option_6985f2b1aeda4a0b9a336c5e606aa710);
#
#     });
# </script>

# %%
data['categories']
# Out:
# [{'digital': '0:13:01',
#   'hours': 0,
#   'minutes': 13,
#   'name': 'Coding',
#   'percent': 100.0,
#   'seconds': 1,
#   'text': '13 mins',
#   'total_seconds': 781.814}]
